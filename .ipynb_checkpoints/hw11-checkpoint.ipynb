# %%
from tensorflow.keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN, LSTM, Bidirectional, Dense
from keras.preprocessing import sequence
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
max_features = 10000
maxlen = 500
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
def train_model(model, x_train, y_train, epochs=5, batch_size=128, validation_split=0.2):
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=validation_split)
    return history

# %%
model_rnn = Sequential()
model_rnn.add(Embedding(max_features, 32))
model_rnn.add(SimpleRNN(32))
model_rnn.add(Dense(1, activation='sigmoid'))

# %%
model_lstm = Sequential()
model_lstm.add(Embedding(max_features, 32))
model_lstm.add(LSTM(32))
model_lstm.add(Dense(1, activation='sigmoid'))

# %%
model_bidirectional = Sequential()
model_bidirectional.add(Embedding(max_features, 32))
model_bidirectional.add(Bidirectional(SimpleRNN(32)))
model_bidirectional.add(Dense(1, activation='sigmoid'))

# %%
model_deep_rnn = Sequential()
model_deep_rnn.add(Embedding(max_features, 32))
model_deep_rnn.add(SimpleRNN(32, return_sequences=True))
model_deep_rnn.add(SimpleRNN(32))
model_deep_rnn.add(Dense(1, activation='sigmoid'))

# %%
print("*****Base RNN*****")
history_rnn = train_model(model_rnn, x_train, y_train)
print("*****LSTM*****")
history_lstm = train_model(model_lstm, x_train, y_train)
print("*****Bidirectional RNN*****")
history_bidirectional = train_model(model_bidirectional, x_train, y_train)
print("*****Deep RNN*****")
history_deep_rnn = train_model(model_deep_rnn, x_train, y_train)
# Out:
# *****Base RNN*****
# Epoch 1/5
# 157/157 [==============================] - 35s 209ms/step - loss: 0.6218 - accuracy: 0.6525 - val_loss: 0.5000 - val_accuracy: 0.7706
# Epoch 2/5
# 157/157 [==============================] - 32s 203ms/step - loss: 0.3793 - accuracy: 0.8404 - val_loss: 0.3604 - val_accuracy: 0.8478
# Epoch 3/5
# 157/157 [==============================] - 31s 199ms/step - loss: 0.2506 - accuracy: 0.9035 - val_loss: 0.3296 - val_accuracy: 0.8600
# Epoch 4/5
# 157/157 [==============================] - 31s 199ms/step - loss: 0.3107 - accuracy: 0.8615 - val_loss: 0.5779 - val_accuracy: 0.6894
# Epoch 5/5
# 157/157 [==============================] - 32s 203ms/step - loss: 0.2803 - accuracy: 0.8866 - val_loss: 0.5917 - val_accuracy: 0.8172
# *****LSTM*****
# Epoch 1/5
# 157/157 [==============================] - 84s 510ms/step - loss: 0.4955 - accuracy: 0.7579 - val_loss: 0.3279 - val_accuracy: 0.8646
# Epoch 2/5
# 157/157 [==============================] - 79s 505ms/step - loss: 0.2568 - accuracy: 0.8995 - val_loss: 0.2925 - val_accuracy: 0.8798
# Epoch 3/5
# 157/157 [==============================] - 78s 498ms/step - loss: 0.1777 - accuracy: 0.9372 - val_loss: 0.3054 - val_accuracy: 0.8714
# Epoch 4/5
# 157/157 [==============================] - 78s 499ms/step - loss: 0.1397 - accuracy: 0.9536 - val_loss: 0.3222 - val_accuracy: 0.8782
# Epoch 5/5
# 157/157 [==============================] - 79s 500ms/step - loss: 0.1178 - accuracy: 0.9610 - val_loss: 0.3899 - val_accuracy: 0.8714
# *****Bidirectional RNN*****
# Epoch 1/5
# 157/157 [==============================] - 42s 243ms/step - loss: 0.6887 - accuracy: 0.5512 - val_loss: 0.6631 - val_accuracy: 0.5470
# Epoch 2/5
# 157/157 [==============================] - 38s 239ms/step - loss: 0.5583 - accuracy: 0.7462 - val_loss: 0.8497 - val_accuracy: 0.5934
# Epoch 3/5
# 157/157 [==============================] - 37s 237ms/step - loss: 0.3693 - accuracy: 0.8479 - val_loss: 0.3646 - val_accuracy: 0.8526
# Epoch 4/5
# 157/157 [==============================] - 37s 235ms/step - loss: 0.2487 - accuracy: 0.9036 - val_loss: 0.3473 - val_accuracy: 0.8580
# Epoch 5/5
# 157/157 [==============================] - 37s 238ms/step - loss: 0.1897 - accuracy: 0.9319 - val_loss: 0.4438 - val_accuracy: 0.8166
# *****Deep RNN*****
# Epoch 1/5
# 157/157 [==============================] - 62s 372ms/step - loss: 0.6789 - accuracy: 0.5534 - val_loss: 0.6535 - val_accuracy: 0.6424
# Epoch 2/5
# 157/157 [==============================] - 58s 369ms/step - loss: 0.5262 - accuracy: 0.7318 - val_loss: 0.6338 - val_accuracy: 0.6390
# Epoch 3/5
# 157/157 [==============================] - 58s 369ms/step - loss: 0.2958 - accuracy: 0.8831 - val_loss: 0.5185 - val_accuracy: 0.7814
# Epoch 4/5
# 157/157 [==============================] - 58s 369ms/step - loss: 0.1025 - accuracy: 0.9679 - val_loss: 0.5477 - val_accuracy: 0.8114
# Epoch 5/5
# 157/157 [==============================] - 58s 369ms/step - loss: 0.0221 - accuracy: 0.9964 - val_loss: 0.7576 - val_accuracy: 0.7638

# %%
import numpy as np

def evaluate_model(model, x_test, y_test):
    y_pred_prob = model.predict(x_test)
    y_pred = np.round(y_pred_prob).astype(int)

    print("Classification Report:\n", classification_report(y_test, y_pred))
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy: {:.2f}%".format(accuracy * 100))
    
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# %%
evaluate_model(model_rnn, x_test, y_test)
evaluate_model(model_lstm, x_test, y_test)
evaluate_model(model_bidirectional, x_test, y_test)
evaluate_model(model_deep_rnn, x_test, y_test)
# Out:
# 782/782 [==============================] - 25s 33ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82     12500
#            1       0.86      0.74      0.80     12500
#
#     accuracy                           0.81     25000
#    macro avg       0.82      0.81      0.81     25000
# weighted avg       0.82      0.81      0.81     25000
#
# Accuracy: 81.06%
# 782/782 [==============================] - 59s 76ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86     12500
#            1       0.85      0.89      0.87     12500
#
#     accuracy                           0.86     25000
#    macro avg       0.86      0.86      0.86     25000
# weighted avg       0.86      0.86      0.86     25000
#
# Accuracy: 86.33%
# 782/782 [==============================] - 37s 47ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.77      0.81     12500
#            1       0.79      0.88      0.83     12500
#
#     accuracy                           0.82     25000
#    macro avg       0.83      0.82      0.82     25000
# weighted avg       0.83      0.82      0.82     25000
#
# Accuracy: 82.18%
# 782/782 [==============================] - 50s 64ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76     12500
#            1       0.76      0.75      0.76     12500
#
#     accuracy                           0.76     25000
#    macro avg       0.76      0.76      0.76     25000
# weighted avg       0.76      0.76      0.76     25000
#
# Accuracy: 75.80%

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Графік точності
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Графік втрат
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
plot_history(history_rnn)
plot_history(history_lstm)
plot_history(history_bidirectional)
plot_history(history_deep_rnn)

# %%
test_loss_rnn, test_acc_rnn = model_rnn.evaluate(x_test, y_test)
print(f'Test accuracy for RNN model: {test_acc_rnn}')

test_loss_lstm, test_acc_lstm = model_lstm.evaluate(x_test, y_test)
print(f'Test accuracy for LSTM model: {test_acc_lstm}')

test_loss_bidirectional, test_acc_bidirectional = model_bidirectional.evaluate(x_test, y_test)
print(f'Test accuracy for Bidirectional model: {test_acc_bidirectional}')

test_loss_deep_rnn, test_acc_deep_rnn = model_deep_rnn.evaluate(x_test, y_test)
print(f'Test accuracy for Deep RNN model: {test_acc_deep_rnn}')
# Out:
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6192 - accuracy: 0.8106
# Test accuracy for RNN model: 0.8106399774551392
# 782/782 [==============================] - 59s 76ms/step - loss: 0.4096 - accuracy: 0.8633
# Test accuracy for LSTM model: 0.863319993019104
# 782/782 [==============================] - 35s 45ms/step - loss: 0.4280 - accuracy: 0.8218
# Test accuracy for Bidirectional model: 0.8217999935150146
# 782/782 [==============================] - 50s 63ms/step - loss: 0.7753 - accuracy: 0.7580
# Test accuracy for Deep RNN model: 0.7580400109291077
